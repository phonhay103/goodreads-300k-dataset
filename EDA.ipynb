# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv(
    'goodreads-300k-dataset/goodreads.csv',
    index_col=0,
)
# Out:
# /var/folders/8r/m2pg_8ks4llg947g5m_m0hqh0000gn/T/ipykernel_2772/2434121399.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
# Pandas-profiling
# from pandas_profiling import ProfileReport
# profile = ProfileReport(df, title="Pandas Profiling Report")
# profile.to_file("pandas_profiling_report.html")

# %%
sns.displot(df.rating, kde=True, bins=150).savefig("rating_K0.png")

# %%
df1 = df[df.rating_count >= 1000]
sns.displot(df1.rating, kde=True, bins=150).savefig("rating_K1000.png")

# %%
bins = (0, 3, 3.5, 4, 4.5, 5)
labels = np.arange(len(bins)-1)
sns.displot(pd.cut(df.rating, bins=bins, labels=labels, include_lowest=True))

# %%
bins = (0, 3, 3.5, 4, 4.5, 5)
labels = np.arange(len(bins)-1)
sns.displot(pd.cut(df1.rating, bins=bins, labels=labels, include_lowest=True))
